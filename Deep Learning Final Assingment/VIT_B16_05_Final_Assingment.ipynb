# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import random
import time
import os
import tensorflow_hub as hub
import keras

SEED = 0

def set_seeds(seed=SEED):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)

def set_global_determinism(seed=SEED):
    set_seeds(seed=seed)

    os.environ['TF_DETERMINISTIC_OPS'] = '1'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
    
    tf.config.threading.set_inter_op_parallelism_threads(1)
    tf.config.threading.set_intra_op_parallelism_threads(1)

set_global_determinism(seed=SEED) # Setting seed for a reproducible code.
print(f'Tensorflow Version: {tf.__version__}')
# Out:
# Tensorflow Version: 2.9.2

# %%
df = np.load('/content/drive/MyDrive/Colab Notebooks/Avaliação - Deep Learning/df224_[0-1].npz')
imagens, rotulos = df['x'], df['y']
rotulos.shape
print("rotulos shape: ", rotulos.shape)
print("rotulos size: ", rotulos.size)
print("rotulos type: ", type(rotulos))
# Out:
# rotulos shape:  (2193,)
# rotulos size:  2193
# rotulos type:  <class 'numpy.ndarray'>

# %%
# Dividindo a base em treinamento e validação com uso da biblioteca SciKit Learn.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df['x'], df['y'], test_size=0.20, random_state=SEED)

# %%
test_nf = np.count_nonzero(y_test == 0)
test_cm = np.count_nonzero(y_test == 1)
train_nf = np.count_nonzero(y_train == 0)
train_cm = np.count_nonzero(y_train == 1)

print(f"""
{20*'='}
Label Distribution
{20*'='}
\n
> Train:
Total: {train_cm + train_nf}
No Findings: {train_nf} ~ {train_nf/(train_nf + train_cm)*100:.4f}%
Cardiomegaly: {train_cm} ~ {train_cm/(train_nf + train_cm)*100:.4f}%
\n
> Test:
Total: {test_cm + test_nf}
No Findings: {test_nf} ~ {test_nf/(test_nf + test_cm)*100:.4f}%
Cardiomegaly: {test_cm} ~ {test_cm/(test_nf + test_cm)*100:.4f}%
""")

del(test_nf, test_cm, train_cm, train_nf)
# Out:
# ====================
# Label Distribution
# ====================
#
#
# > Train:
# Total: 1754
# No Findings: 875 ~ 49.8860%
# Cardiomegaly: 879 ~ 50.1140%
#
#
# > Test:
# Total: 439
# No Findings: 225 ~ 51.2528%
# Cardiomegaly: 214 ~ 48.7472%

# %% [markdown]
# ## Warm-up + [cosine | linear] LR

# %%
num_classes = 2
EPOCHS = 100
BATCH_SIZE = 32
# AUTO = tf.data.AUTOTUNE

# %%
# Learning rate scheduling (warm-up + [cosine | linear])
## Reference: https://www.kaggle.com/ashusma/training-rfcx-tensorflow-tpu-effnet-b2


class WarmUpCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(
        self, learning_rate_base, total_steps, warmup_learning_rate, warmup_steps
    ):
        super(WarmUpCosine, self).__init__()

        self.learning_rate_base = learning_rate_base
        self.total_steps = total_steps
        self.warmup_learning_rate = warmup_learning_rate
        self.warmup_steps = warmup_steps
        self.pi = tf.constant(np.pi)

    def __call__(self, step):
        if self.total_steps < self.warmup_steps:
            raise ValueError("Total_steps must be larger or equal to warmup_steps.")
        learning_rate = (
            0.5
            * self.learning_rate_base
            * (
                1
                + tf.cos(
                    self.pi
                    * (tf.cast(step, tf.float32) - self.warmup_steps)
                    / float(self.total_steps - self.warmup_steps)
                )
            )
        )

        if self.warmup_steps > 0:
            if self.learning_rate_base < self.warmup_learning_rate:
                raise ValueError(
                    "Learning_rate_base must be larger or equal to "
                    "warmup_learning_rate."
                )
            slope = (
                self.learning_rate_base - self.warmup_learning_rate
            ) / self.warmup_steps
            warmup_rate = slope * tf.cast(step, tf.float32) + self.warmup_learning_rate
            learning_rate = tf.where(
                step < self.warmup_steps, warmup_rate, learning_rate
            )
        return tf.where(
            step > self.total_steps, 0.0, learning_rate, name="learning_rate"
        )

# %%
num_train = len(X_train)
num_test = len(X_test)

# %%
TOTAL_STEPS = int((num_train / BATCH_SIZE) * EPOCHS)
WARMUP_STEPS = 10
INIT_LR = 0.03
WAMRUP_LR = 0.006

print(TOTAL_STEPS)
# Out:
# 5481

# %%
scheduled_lrs = WarmUpCosine(
    learning_rate_base=INIT_LR,
    total_steps=TOTAL_STEPS,
    warmup_learning_rate=WAMRUP_LR,
    warmup_steps=WARMUP_STEPS,
)

lrs = [scheduled_lrs(step) for step in range(TOTAL_STEPS)]
plt.plot(lrs)
plt.xlabel("Step", fontsize=14)
plt.ylabel("LR", fontsize=14)
plt.show()

# %%
optimizer = keras.optimizers.SGD(scheduled_lrs, clipnorm=1.0)
loss = keras.losses.SparseCategoricalCrossentropy()
initializer = keras.initializers.HeNormal(SEED)

# %% [markdown]
# ## ViT B8

# %%
import tensorflow.keras as keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Retornaremos o melhor conjunto de pesos que maximize a acurácia do modelo nos dados de validação
callback_parada = EarlyStopping(monitor='val_accuracy',
                                min_delta = 0.001,
                                patience = 20,
                                verbose = True,
                                mode='max',
                                baseline = None,
                                restore_best_weights=True)

# %%
def plotHistory(history, patience):
  import matplotlib.pyplot as plt

  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  plt.figure(figsize=(8, 8))
  plt.subplot(2, 1, 1)
  plt.plot(acc, label='Training Accuracy')
  plt.plot(val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.plot([history.epoch[-1]-int(patience),history.epoch[-1]-int(patience)],
            plt.ylim(), label='Best Epoch')
  plt.legend(loc='lower right')
  plt.ylabel('Accuracy')
  plt.title('Training and Validation Accuracy')

  plt.subplot(2, 1, 2)
  plt.plot(loss, label='Training Loss')
  plt.plot(val_loss, label='Validation Loss')
  plt.plot([history.epoch[-1]-int(patience),history.epoch[-1]-int(patience)],
            plt.ylim(), label='Best Epoch')
  plt.legend(loc='upper right')
  plt.ylabel('Sparse Categorical Cross Entropy')
  plt.title('Training and Validation Loss')
  plt.xlabel('epoch')
  plt.show()

# %%
## Making tensor dataset to fit vit_B16_fe input shape

x_train = np.expand_dims(X_train, axis=-1)
x_test = np.expand_dims(X_test, axis=-1)

train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(BATCH_SIZE).prefetch(SEED)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH_SIZE).prefetch(SEED)

# %%
import tensorflow_hub as hub

def get_model(
    handle="https://tfhub.dev/sayakpaul/vit_b16_fe/1", 
    num_classes=2,
):
    hub_layer = hub.KerasLayer(handle, trainable=False, name = 'vit_b16_fe')

    model = keras.Sequential(
        [
            keras.layers.InputLayer((224, 224, 3)),
            hub_layer,
            keras.layers.Dense(512, activation="relu", kernel_initializer = initializer),
            keras.layers.Dropout(0.5),
            keras.layers.Dense(num_classes, activation="softmax")
            
        ]
    )
    return model

model_ViT = get_model()
model_ViT.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit_b16_fe (KerasLayer)     (None, 768)               85798656
#
#  dense_2 (Dense)             (None, 512)               393728
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 86,193,410
# Trainable params: 394,754
# Non-trainable params: 85,798,656
# _________________________________________________________________

# %%
model_ViT.compile(loss=loss, optimizer=optimizer, metrics=["accuracy"])
t0 = time.time()
history_VIT = model_ViT.fit(train_dataset,
                    validation_data = test_dataset,
                    epochs=EPOCHS,
                    callbacks=[callback_parada])
print("Training time:", time.time()-t0)
# Out:
# Epoch 1/100
# 55/55 [==============================] - 39s 383ms/step - loss: 1.2256 - accuracy: 0.5262 - val_loss: 0.7695 - val_accuracy: 0.5695
# Epoch 2/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.9008 - accuracy: 0.5684 - val_loss: 0.8223 - val_accuracy: 0.5308
# Epoch 3/100
# 55/55 [==============================] - 6s 114ms/step - loss: 0.7902 - accuracy: 0.5747 - val_loss: 0.6640 - val_accuracy: 0.5968
# Epoch 4/100
# 55/55 [==============================] - 6s 114ms/step - loss: 0.7061 - accuracy: 0.6152 - val_loss: 0.6541 - val_accuracy: 0.6014
# Epoch 5/100
# 55/55 [==============================] - 6s 114ms/step - loss: 0.6773 - accuracy: 0.6266 - val_loss: 0.5870 - val_accuracy: 0.7267
# Epoch 6/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.6541 - accuracy: 0.6391 - val_loss: 0.5844 - val_accuracy: 0.7221
# Epoch 7/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.6265 - accuracy: 0.6665 - val_loss: 0.5725 - val_accuracy: 0.7221
# Epoch 8/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.6191 - accuracy: 0.6659 - val_loss: 0.5725 - val_accuracy: 0.7130
# Epoch 9/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.6071 - accuracy: 0.6733 - val_loss: 0.5649 - val_accuracy: 0.7221
# Epoch 10/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.5987 - accuracy: 0.6802 - val_loss: 0.5762 - val_accuracy: 0.6970
# Epoch 11/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.5975 - accuracy: 0.6836 - val_loss: 0.5680 - val_accuracy: 0.7084
# Epoch 12/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.5735 - accuracy: 0.7030 - val_loss: 0.5665 - val_accuracy: 0.7175
# Epoch 13/100
# 55/55 [==============================] - 6s 114ms/step - loss: 0.5828 - accuracy: 0.6847 - val_loss: 0.5530 - val_accuracy: 0.7335
# Epoch 14/100
# 55/55 [==============================] - 6s 114ms/step - loss: 0.5605 - accuracy: 0.7087 - val_loss: 0.5583 - val_accuracy: 0.7358
# Epoch 15/100
# 55/55 [==============================] - 6s 109ms/step - loss: 0.5530 - accuracy: 0.7132 - val_loss: 0.5642 - val_accuracy: 0.7244
# Epoch 16/100
# 55/55 [==============================] - 6s 109ms/step - loss: 0.5517 - accuracy: 0.7223 - val_loss: 0.5495 - val_accuracy: 0.7175
# Epoch 17/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.5386 - accuracy: 0.7338 - val_loss: 0.5514 - val_accuracy: 0.7312
# Epoch 18/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.5277 - accuracy: 0.7320 - val_loss: 0.5446 - val_accuracy: 0.7221
# Epoch 19/100
# 55/55 [==============================] - 6s 114ms/step - loss: 0.5312 - accuracy: 0.7292 - val_loss: 0.5471 - val_accuracy: 0.7403
# Epoch 20/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.5216 - accuracy: 0.7349 - val_loss: 0.5475 - val_accuracy: 0.7175
# Epoch 21/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.5176 - accuracy: 0.7429 - val_loss: 0.5499 - val_accuracy: 0.7198
# Epoch 22/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4978 - accuracy: 0.7548 - val_loss: 0.5310 - val_accuracy: 0.7380
# Epoch 23/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.5081 - accuracy: 0.7537 - val_loss: 0.5405 - val_accuracy: 0.7358
# Epoch 24/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.5012 - accuracy: 0.7617 - val_loss: 0.5461 - val_accuracy: 0.7380
# Epoch 25/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.5002 - accuracy: 0.7491 - val_loss: 0.5389 - val_accuracy: 0.7380
# Epoch 26/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.5001 - accuracy: 0.7520 - val_loss: 0.5416 - val_accuracy: 0.7244
# Epoch 27/100
# 55/55 [==============================] - 6s 114ms/step - loss: 0.4872 - accuracy: 0.7634 - val_loss: 0.5361 - val_accuracy: 0.7472
# Epoch 28/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4773 - accuracy: 0.7702 - val_loss: 0.5440 - val_accuracy: 0.7312
# Epoch 29/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4775 - accuracy: 0.7594 - val_loss: 0.5403 - val_accuracy: 0.7472
# Epoch 30/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4678 - accuracy: 0.7851 - val_loss: 0.5566 - val_accuracy: 0.7221
# Epoch 31/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4660 - accuracy: 0.7765 - val_loss: 0.5376 - val_accuracy: 0.7267
# Epoch 32/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4552 - accuracy: 0.7794 - val_loss: 0.5531 - val_accuracy: 0.7312
# Epoch 33/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4574 - accuracy: 0.7748 - val_loss: 0.5483 - val_accuracy: 0.7312
# Epoch 34/100
# 55/55 [==============================] - 6s 114ms/step - loss: 0.4632 - accuracy: 0.7811 - val_loss: 0.5469 - val_accuracy: 0.7494
# Epoch 35/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4506 - accuracy: 0.7936 - val_loss: 0.5443 - val_accuracy: 0.7380
# Epoch 36/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4364 - accuracy: 0.7976 - val_loss: 0.5486 - val_accuracy: 0.7358
# Epoch 37/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4407 - accuracy: 0.7834 - val_loss: 0.5421 - val_accuracy: 0.7335
# Epoch 38/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4215 - accuracy: 0.8050 - val_loss: 0.5538 - val_accuracy: 0.7312
# Epoch 39/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4415 - accuracy: 0.7959 - val_loss: 0.5291 - val_accuracy: 0.7380
# Epoch 40/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4128 - accuracy: 0.8170 - val_loss: 0.5383 - val_accuracy: 0.7312
# Epoch 41/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4152 - accuracy: 0.8079 - val_loss: 0.5428 - val_accuracy: 0.7289
# Epoch 42/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4134 - accuracy: 0.8107 - val_loss: 0.5543 - val_accuracy: 0.7221
# Epoch 43/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4045 - accuracy: 0.8079 - val_loss: 0.5356 - val_accuracy: 0.7289
# Epoch 44/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4027 - accuracy: 0.8158 - val_loss: 0.5543 - val_accuracy: 0.7289
# Epoch 45/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.3973 - accuracy: 0.8107 - val_loss: 0.5652 - val_accuracy: 0.7175
# Epoch 46/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.4007 - accuracy: 0.8067 - val_loss: 0.5542 - val_accuracy: 0.7312
# Epoch 47/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.3922 - accuracy: 0.8170 - val_loss: 0.5524 - val_accuracy: 0.7358
# Epoch 48/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.3958 - accuracy: 0.8170 - val_loss: 0.5599 - val_accuracy: 0.7221
# Epoch 49/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.3918 - accuracy: 0.8267 - val_loss: 0.5442 - val_accuracy: 0.7289
# Epoch 50/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.3879 - accuracy: 0.8318 - val_loss: 0.5483 - val_accuracy: 0.7426
# Epoch 51/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.3849 - accuracy: 0.8221 - val_loss: 0.5450 - val_accuracy: 0.7267
# Epoch 52/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.3832 - accuracy: 0.8284 - val_loss: 0.5432 - val_accuracy: 0.7312
# Epoch 53/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.3894 - accuracy: 0.8261 - val_loss: 0.5452 - val_accuracy: 0.7380
# Epoch 54/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3831 - accuracy: 0.8238Restoring model weights from the end of the best epoch: 34.
# 55/55 [==============================] - 6s 112ms/step - loss: 0.3831 - accuracy: 0.8238 - val_loss: 0.5431 - val_accuracy: 0.7267
# Epoch 54: early stopping
# Training time: 360.8815519809723

# %%
plotHistory(history_VIT, 20)

# %%
t0 = time.time()
pred_ViT = model_ViT.predict(X_test)
print("Prediction time:", time.time()-t0)
y_pred_ViT = np.argmax(pred_ViT, axis=1)

print(f'\nThe average accuracy of the exploring model on Test Data is: {accuracy_score(y_pred_ViT, y_test)*100:.4f}%')
hm = sns.heatmap(confusion_matrix(y_test, y_pred_ViT), annot=True, fmt='g', cmap="YlGnBu")
hm.set(xlabel="Predicted Label", ylabel="True Label")
# Out:
# 14/14 [==============================] - 2s 85ms/step
# Prediction time: 2.3090949058532715
#
# The average accuracy of the exploring model on Test Data is: 74.9431%
# [Text(33.0, 0.5, 'True Label'), Text(0.5, 15.0, 'Predicted Label')]

# %%
# !nvidia-smi -L
# Out:
# GPU 0: A100-SXM4-40GB (UUID: GPU-855feb2a-37bc-23b2-94d4-2610f06dd773)
