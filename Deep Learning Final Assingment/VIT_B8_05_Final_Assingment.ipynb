# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import random
import time
import os
import tensorflow_hub as hub
import keras

SEED = 0

def set_seeds(seed=SEED):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)

def set_global_determinism(seed=SEED):
    set_seeds(seed=seed)

    os.environ['TF_DETERMINISTIC_OPS'] = '1'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
    
    tf.config.threading.set_inter_op_parallelism_threads(1)
    tf.config.threading.set_intra_op_parallelism_threads(1)

set_global_determinism(seed=SEED) # Setting seed for a reproducible code.
print(f'Tensorflow Version: {tf.__version__}')
# Out:
# Tensorflow Version: 2.9.2

# %%
df = np.load('/content/drive/MyDrive/Colab Notebooks/Avaliação - Deep Learning/df224_[0-1].npz')
imagens, rotulos = df['x'], df['y']
rotulos.shape
print("rotulos shape: ", rotulos.shape)
print("rotulos size: ", rotulos.size)
print("rotulos type: ", type(rotulos))
# Out:
# rotulos shape:  (2193,)
# rotulos size:  2193
# rotulos type:  <class 'numpy.ndarray'>

# %%
# Dividindo a base em treinamento e validação com uso da biblioteca SciKit Learn.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df['x'], df['y'], test_size=0.20, random_state=SEED)

# %%
test_nf = np.count_nonzero(y_test == 0)
test_cm = np.count_nonzero(y_test == 1)
train_nf = np.count_nonzero(y_train == 0)
train_cm = np.count_nonzero(y_train == 1)

print(f"""
{20*'='}
Label Distribution
{20*'='}
\n
> Train:
Total: {train_cm + train_nf}
No Findings: {train_nf} ~ {train_nf/(train_nf + train_cm)*100:.4f}%
Cardiomegaly: {train_cm} ~ {train_cm/(train_nf + train_cm)*100:.4f}%
\n
> Test:
Total: {test_cm + test_nf}
No Findings: {test_nf} ~ {test_nf/(test_nf + test_cm)*100:.4f}%
Cardiomegaly: {test_cm} ~ {test_cm/(test_nf + test_cm)*100:.4f}%
""")

del(test_nf, test_cm, train_cm, train_nf)
# Out:
# ====================
# Label Distribution
# ====================
#
#
# > Train:
# Total: 1754
# No Findings: 875 ~ 49.8860%
# Cardiomegaly: 879 ~ 50.1140%
#
#
# > Test:
# Total: 439
# No Findings: 225 ~ 51.2528%
# Cardiomegaly: 214 ~ 48.7472%

# %% [markdown]
# ## Warm-up + [cosine | linear] LR

# %%
num_classes = 2
EPOCHS = 100
BATCH_SIZE = 32
# AUTO = tf.data.AUTOTUNE

# %%
# Learning rate scheduling (warm-up + [cosine | linear])
## Reference: https://www.kaggle.com/ashusma/training-rfcx-tensorflow-tpu-effnet-b2


class WarmUpCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(
        self, learning_rate_base, total_steps, warmup_learning_rate, warmup_steps
    ):
        super(WarmUpCosine, self).__init__()

        self.learning_rate_base = learning_rate_base
        self.total_steps = total_steps
        self.warmup_learning_rate = warmup_learning_rate
        self.warmup_steps = warmup_steps
        self.pi = tf.constant(np.pi)

    def __call__(self, step):
        if self.total_steps < self.warmup_steps:
            raise ValueError("Total_steps must be larger or equal to warmup_steps.")
        learning_rate = (
            0.5
            * self.learning_rate_base
            * (
                1
                + tf.cos(
                    self.pi
                    * (tf.cast(step, tf.float32) - self.warmup_steps)
                    / float(self.total_steps - self.warmup_steps)
                )
            )
        )

        if self.warmup_steps > 0:
            if self.learning_rate_base < self.warmup_learning_rate:
                raise ValueError(
                    "Learning_rate_base must be larger or equal to "
                    "warmup_learning_rate."
                )
            slope = (
                self.learning_rate_base - self.warmup_learning_rate
            ) / self.warmup_steps
            warmup_rate = slope * tf.cast(step, tf.float32) + self.warmup_learning_rate
            learning_rate = tf.where(
                step < self.warmup_steps, warmup_rate, learning_rate
            )
        return tf.where(
            step > self.total_steps, 0.0, learning_rate, name="learning_rate"
        )

# %%
num_train = len(X_train)
num_test = len(X_test)

# %%
TOTAL_STEPS = int((num_train / BATCH_SIZE) * EPOCHS)
WARMUP_STEPS = 10
INIT_LR = 0.03
WAMRUP_LR = 0.006

print(TOTAL_STEPS)
# Out:
# 5481

# %%
scheduled_lrs = WarmUpCosine(
    learning_rate_base=INIT_LR,
    total_steps=TOTAL_STEPS,
    warmup_learning_rate=WAMRUP_LR,
    warmup_steps=WARMUP_STEPS,
)

lrs = [scheduled_lrs(step) for step in range(TOTAL_STEPS)]
plt.plot(lrs)
plt.xlabel("Step", fontsize=14)
plt.ylabel("LR", fontsize=14)
plt.show()

# %%
optimizer = keras.optimizers.SGD(scheduled_lrs, clipnorm=1.0)
loss = keras.losses.SparseCategoricalCrossentropy()
initializer = keras.initializers.HeNormal(SEED)

# %% [markdown]
# ## ViT B8

# %%
import tensorflow.keras as keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Retornaremos o melhor conjunto de pesos que maximize a acurácia do modelo nos dados de validação
callback_parada = EarlyStopping(monitor='val_accuracy',
                                min_delta = 0.001,
                                patience = 20,
                                verbose = True,
                                mode='max',
                                baseline = None,
                                restore_best_weights=True)

# %%
def plotHistory(history, patience):
  import matplotlib.pyplot as plt

  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  plt.figure(figsize=(8, 8))
  plt.subplot(2, 1, 1)
  plt.plot(acc, label='Training Accuracy')
  plt.plot(val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.plot([history.epoch[-1]-int(patience),history.epoch[-1]-int(patience)],
            plt.ylim(), label='Best Epoch')
  plt.legend(loc='lower right')
  plt.ylabel('Accuracy')
  plt.title('Training and Validation Accuracy')

  plt.subplot(2, 1, 2)
  plt.plot(loss, label='Training Loss')
  plt.plot(val_loss, label='Validation Loss')
  plt.plot([history.epoch[-1]-int(patience),history.epoch[-1]-int(patience)],
            plt.ylim(), label='Best Epoch')
  plt.legend(loc='upper right')
  plt.ylabel('Sparse Categorical Cross Entropy')
  plt.title('Training and Validation Loss')
  plt.xlabel('epoch')
  plt.show()

# %%
## Making tensor dataset to fit vit_L16_fe input shape

x_train = np.expand_dims(X_train, axis=-1)
x_test = np.expand_dims(X_test, axis=-1)

train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(BATCH_SIZE).prefetch(SEED)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH_SIZE).prefetch(SEED)

# %%
import tensorflow_hub as hub

def get_model(
    handle="https://tfhub.dev/sayakpaul/vit_b8_fe/1", 
    num_classes=2,
):
    hub_layer = hub.KerasLayer(handle, trainable=False, name = 'vit_b8_fe')

    model = keras.Sequential(
        [
            keras.layers.InputLayer((224, 224, 3)),
            hub_layer,
            keras.layers.Dense(512, activation="relu", kernel_initializer = initializer),
            keras.layers.Dropout(0.5),
            keras.layers.Dense(num_classes, activation="softmax")
            
        ]
    )
    return model

model_ViT = get_model()
model_ViT.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit_b8_fe (KerasLayer)      (None, 768)               85807872
#
#  dense (Dense)               (None, 512)               393728
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 86,202,626
# Trainable params: 394,754
# Non-trainable params: 85,807,872
# _________________________________________________________________

# %%
model_ViT.compile(loss=loss, optimizer=optimizer, metrics=["accuracy"])
t0 = time.time()
history_VIT = model_ViT.fit(train_dataset,
                    validation_data = test_dataset,
                    epochs=EPOCHS,
                    callbacks=[callback_parada])
print("Training time:", time.time()-t0)
# Out:
# Epoch 1/100
# 55/55 [==============================] - 62s 787ms/step - loss: 2.1838 - accuracy: 0.5137 - val_loss: 1.3586 - val_accuracy: 0.4989
# Epoch 2/100
# 55/55 [==============================] - 26s 471ms/step - loss: 1.2961 - accuracy: 0.5587 - val_loss: 0.9187 - val_accuracy: 0.5353
# Epoch 3/100
# 55/55 [==============================] - 26s 471ms/step - loss: 1.0020 - accuracy: 0.5667 - val_loss: 0.8136 - val_accuracy: 0.5558
# Epoch 4/100
# 55/55 [==============================] - 26s 472ms/step - loss: 0.8617 - accuracy: 0.5781 - val_loss: 0.6919 - val_accuracy: 0.5945
# Epoch 5/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.8023 - accuracy: 0.5758 - val_loss: 0.6674 - val_accuracy: 0.5809
# Epoch 6/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.7563 - accuracy: 0.5906 - val_loss: 0.6448 - val_accuracy: 0.5877
# Epoch 7/100
# 55/55 [==============================] - 26s 472ms/step - loss: 0.6922 - accuracy: 0.6226 - val_loss: 0.6093 - val_accuracy: 0.6583
# Epoch 8/100
# 55/55 [==============================] - 26s 472ms/step - loss: 0.6835 - accuracy: 0.6049 - val_loss: 0.5981 - val_accuracy: 0.6674
# Epoch 9/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.6401 - accuracy: 0.6494 - val_loss: 0.6042 - val_accuracy: 0.6355
# Epoch 10/100
# 55/55 [==============================] - 26s 471ms/step - loss: 0.6245 - accuracy: 0.6682 - val_loss: 0.5704 - val_accuracy: 0.7175
# Epoch 11/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.6155 - accuracy: 0.6642 - val_loss: 0.5604 - val_accuracy: 0.7039
# Epoch 12/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.6107 - accuracy: 0.6813 - val_loss: 0.5867 - val_accuracy: 0.7039
# Epoch 13/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.5897 - accuracy: 0.7013 - val_loss: 0.5699 - val_accuracy: 0.7107
# Epoch 14/100
# 55/55 [==============================] - 26s 472ms/step - loss: 0.5908 - accuracy: 0.6933 - val_loss: 0.5580 - val_accuracy: 0.7267
# Epoch 15/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.5796 - accuracy: 0.7178 - val_loss: 0.5541 - val_accuracy: 0.7244
# Epoch 16/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.5706 - accuracy: 0.6938 - val_loss: 0.5510 - val_accuracy: 0.7244
# Epoch 17/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.5644 - accuracy: 0.7218 - val_loss: 0.5514 - val_accuracy: 0.7175
# Epoch 18/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.5637 - accuracy: 0.7098 - val_loss: 0.5520 - val_accuracy: 0.7244
# Epoch 19/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.5639 - accuracy: 0.7166 - val_loss: 0.5561 - val_accuracy: 0.7244
# Epoch 20/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.5550 - accuracy: 0.7081 - val_loss: 0.5562 - val_accuracy: 0.7198
# Epoch 21/100
# 55/55 [==============================] - 26s 471ms/step - loss: 0.5311 - accuracy: 0.7429 - val_loss: 0.5486 - val_accuracy: 0.7335
# Epoch 22/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.5479 - accuracy: 0.7127 - val_loss: 0.5510 - val_accuracy: 0.7221
# Epoch 23/100
# 55/55 [==============================] - 26s 471ms/step - loss: 0.5224 - accuracy: 0.7417 - val_loss: 0.5413 - val_accuracy: 0.7358
# Epoch 24/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.5224 - accuracy: 0.7486 - val_loss: 0.5424 - val_accuracy: 0.7289
# Epoch 25/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.5130 - accuracy: 0.7548 - val_loss: 0.5627 - val_accuracy: 0.7039
# Epoch 26/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.5117 - accuracy: 0.7440 - val_loss: 0.5403 - val_accuracy: 0.7335
# Epoch 27/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.5143 - accuracy: 0.7440 - val_loss: 0.5456 - val_accuracy: 0.7107
# Epoch 28/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.5163 - accuracy: 0.7457 - val_loss: 0.5390 - val_accuracy: 0.7358
# Epoch 29/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4992 - accuracy: 0.7611 - val_loss: 0.5406 - val_accuracy: 0.7107
# Epoch 30/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4880 - accuracy: 0.7674 - val_loss: 0.5418 - val_accuracy: 0.7084
# Epoch 31/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4914 - accuracy: 0.7628 - val_loss: 0.5456 - val_accuracy: 0.7107
# Epoch 32/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4734 - accuracy: 0.7765 - val_loss: 0.5292 - val_accuracy: 0.7335
# Epoch 33/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4631 - accuracy: 0.7777 - val_loss: 0.5276 - val_accuracy: 0.7221
# Epoch 34/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4633 - accuracy: 0.7891 - val_loss: 0.5369 - val_accuracy: 0.7335
# Epoch 35/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4649 - accuracy: 0.7777 - val_loss: 0.5347 - val_accuracy: 0.7335
# Epoch 36/100
# 55/55 [==============================] - 26s 471ms/step - loss: 0.4657 - accuracy: 0.7737 - val_loss: 0.5263 - val_accuracy: 0.7403
# Epoch 37/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4536 - accuracy: 0.7856 - val_loss: 0.5297 - val_accuracy: 0.7335
# Epoch 38/100
# 55/55 [==============================] - 26s 471ms/step - loss: 0.4588 - accuracy: 0.7811 - val_loss: 0.5366 - val_accuracy: 0.7494
# Epoch 39/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4419 - accuracy: 0.7902 - val_loss: 0.5388 - val_accuracy: 0.7267
# Epoch 40/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4494 - accuracy: 0.7930 - val_loss: 0.5294 - val_accuracy: 0.7244
# Epoch 41/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4447 - accuracy: 0.7868 - val_loss: 0.5261 - val_accuracy: 0.7335
# Epoch 42/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4303 - accuracy: 0.8062 - val_loss: 0.5265 - val_accuracy: 0.7358
# Epoch 43/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4346 - accuracy: 0.7908 - val_loss: 0.5300 - val_accuracy: 0.7312
# Epoch 44/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4138 - accuracy: 0.8193 - val_loss: 0.5431 - val_accuracy: 0.7312
# Epoch 45/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4234 - accuracy: 0.7999 - val_loss: 0.5332 - val_accuracy: 0.7267
# Epoch 46/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.3992 - accuracy: 0.8147 - val_loss: 0.5379 - val_accuracy: 0.7380
# Epoch 47/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4138 - accuracy: 0.8141 - val_loss: 0.5255 - val_accuracy: 0.7449
# Epoch 48/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4027 - accuracy: 0.8158 - val_loss: 0.5378 - val_accuracy: 0.7312
# Epoch 49/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4085 - accuracy: 0.8176 - val_loss: 0.5348 - val_accuracy: 0.7426
# Epoch 50/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.3993 - accuracy: 0.8267 - val_loss: 0.5358 - val_accuracy: 0.7380
# Epoch 51/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.3888 - accuracy: 0.8221 - val_loss: 0.5294 - val_accuracy: 0.7380
# Epoch 52/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.3851 - accuracy: 0.8324 - val_loss: 0.5287 - val_accuracy: 0.7335
# Epoch 53/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.4068 - accuracy: 0.8176 - val_loss: 0.5426 - val_accuracy: 0.7472
# Epoch 54/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.3820 - accuracy: 0.8255 - val_loss: 0.5272 - val_accuracy: 0.7335
# Epoch 55/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.3848 - accuracy: 0.8164 - val_loss: 0.5295 - val_accuracy: 0.7449
# Epoch 56/100
# 55/55 [==============================] - 26s 466ms/step - loss: 0.3866 - accuracy: 0.8233 - val_loss: 0.5353 - val_accuracy: 0.7358
# Epoch 57/100
# 55/55 [==============================] - 26s 467ms/step - loss: 0.3758 - accuracy: 0.8227 - val_loss: 0.5222 - val_accuracy: 0.7335
# Epoch 58/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3753 - accuracy: 0.8358Restoring model weights from the end of the best epoch: 38.
# 55/55 [==============================] - 26s 470ms/step - loss: 0.3753 - accuracy: 0.8358 - val_loss: 0.5348 - val_accuracy: 0.7403
# Epoch 58: early stopping
# Training time: 1524.7375764846802

# %%
plotHistory(history_VIT, 20)

# %%
t0 = time.time()
pred_ViT = model_ViT.predict(X_test)
print("Prediction time:", time.time()-t0)
y_pred_ViT = np.argmax(pred_ViT, axis=1)

print(f'\nThe average accuracy of the exploring model on Test Data is: {accuracy_score(y_pred_ViT, y_test)*100:.4f}%')
hm = sns.heatmap(confusion_matrix(y_test, y_pred_ViT), annot=True, fmt='g', cmap="YlGnBu")
hm.set(xlabel="Predicted Label", ylabel="True Label")
# Out:
# 14/14 [==============================] - 6s 370ms/step
# Prediction time: 6.119739532470703
#
# The average accuracy of the exploring model on Test Data is: 74.9431%
# [Text(33.0, 0.5, 'True Label'), Text(0.5, 15.0, 'Predicted Label')]

# %%
# !nvidia-smi
# Out:
# Thu Nov 24 13:08:27 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P0    70W / 400W |   5532MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
